# %% [markdown]
# # Bagian 1

# %%
# !pip install mne

# %%
# !pip install numpy scipy scikit-learn wfdb pyprep wandb
# Out:
# ...
#   Using cached pandas-3.0.6-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 5.4 MB/s  0:00:01m 5.4 MB/s eta 0:00:01
# ...
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 6.3 MB/s  0:00:01.3 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [wfdb]━━━━ 15/17 [aiohttp]cikit-learn]
# ...

# %%
# !pip install ishneholterlib==2017.4.11 pythoncrc
# Out:
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Created wheel for ishneholterlib: filename=ishneholterlib-2017.4.11-py3-none-any.whl size=7503 sha256=094de6152fd22ab7f26d318bb7788530d8c92f6157a4650ef4fa3dbb31722bd1
#   Stored in directory: /Users/jergal/Library/Caches/pip/wheels/ca/4b/be/1ea7fcaee5439008239bd3c06eeb8d4d813fe7e08429fc424c
# Successfully built ishneholterlib
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ishneholterlib]
# ...

# %%
# !pip install pyECG==0.0.9.1 --no-deps
# Out:
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# - PyPREP merupakan library Python yang mengimplementasikan PREP (Preprocessing Pipeline) untuk melakukan preprocessing pada data EEG (Electroencephalography). Library ini bekerja bersama MNE-Python dan digunakan untuk membantu membersihkan data EEG sebelum dilakukan analisis lebih lanjut.
# - SciPy (Scientific Python) merupakan library Python untuk melakukan berbagai perhitungan ilmiah, matematika, teknik, dan statistika. SciPy dibangun untuk bekerja bersama NumPy dan menyediakan berbagai algoritma yang tidak tersedia secara langsung pada NumPy.
# - Weights & Biases atau W&B (wandb) merupakan library yang digunakan untuk melakukan experiment tracking dalam pengembangan Machine Learning.
# - pyECG merupakan library Python yang dibuat untuk bekerja dengan data ECG (Electrocardiogram). ECG merupakan sinyal yang merekam aktivitas listrik jantung.

# %% [markdown]
# # Bagian 2

# %% [markdown]
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Jawaban:
# Salah satu contoh pelanggaran etika adalah menggunakan data pribadi seseorang untuk melatih sistem AI tanpa dasar yang sah. Contohnya, perusahaan mengambil foto wajah pengguna dari internet tanpa izin atau pemberitahuan yang jelas.
#
# Tindakan tersebut dapat melanggar privasi dan berpotensi melanggar UU No. 27 Tahun 2022 tentang Pelindungan Data Pribadi apabila data diperoleh atau digunakan secara melawan hukum.
#
# Contoh lain adalah menggunakan AI untuk membuat deepfake, suara palsu, atau identitas palsu untuk melakukan penipuan. Selain tidak etis karena merugikan orang lain, tindakan tersebut juga dapat melanggar hukum apabila digunakan untuk memperoleh keuntungan atau menyebabkan kerugian.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# Jawaban:
# Pengembangan dan penggunaan AI membutuhkan komputer berkemampuan tinggi seperti GPU yang biasanya dijalankan di pusat data. Hal ini menyebabkan konsumsi listrik yang besar dan dapat meningkatkan emisi karbon apabila sumber listrik masih berasal dari bahan bakar fosil.
#
# Selain listrik, pusat data juga membutuhkan sistem pendingin yang dapat menggunakan air dalam jumlah besar. Produksi dan penggantian perangkat keras seperti GPU juga dapat menghasilkan limbah elektronik.
#
# Menurut saya, beberapa cara untuk mengurangi dampak tersebut adalah menggunakan model AI yang lebih kecil jika memungkinkan, meningkatkan efisiensi model, menggunakan energi terbarukan, serta menggunakan perangkat keras selama masih layak digunakan.
#
# Dengan begitu, perkembangan AI tetap dapat dilakukan tanpa mengabaikan dampaknya terhadap lingkungan.
